# %%
import os
import cv2
import matplotlib.pyplot as plt

# %%
os.chdir("/Users/arnorfati/Documents/Data/keras_dataset/")

# %%
# image_a = cv2.imread("a.jpeg", cv2.IMREAD_ANYCOLOR)
# image_b = cv2.imread("b.png", cv2.IMREAD_ANYCOLOR)

# a = image_a[0:300,300:600]
# a = cv2.resize(a, dsize=(220, 220), interpolation=cv2.INTER_AREA)
# b = image_b[230:450,430:650]

# %%
content = cv2.imread("hai.jpg", cv2.IMREAD_ANYCOLOR)
style = cv2.imread("face_man.jpg", cv2.IMREAD_ANYCOLOR)
style.shape

# %%
a = style[:200,:200]

# %%
style = cv2.imread("bb2.jpeg", cv2.IMREAD_ANYCOLOR)

# %%
a = cv2.GaussianBlur(a,ksize = (5,5),sigmaX = 0)
# a = cv2.GaussianBlur(a,ksize = (5,5),sigmaX = 0)
plt.imshow(a)

# %%
plt.subplot(121)
plt.imshow(a)
plt.subplot(122)
plt.imshow(b)

# %%
cv2.imwrite('face_man.png', style[:380,:380])
# cv2.imwrite('bb.png', b)
# Out:
# True

# %%
content = cv2.imread("hai.png", cv2.IMREAD_ANYCOLOR)

# %%
plt.subplot(121)
plt.imshow(content[20:400,20:400])

# %%
style = cv2.imread("face_man.png", cv2.IMREAD_ANYCOLOR)

# %%
plt.subplot(121)
plt.imshow(style[:380,:380])
