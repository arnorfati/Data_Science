# %%
import os
import pandas as pd

# %%
os.chdir('/Users/arnorfati/Documents/Data/엘포인트')

# %%
os.getcwd()
# Out:
# '/Users/arnorfati/Documents/Data/엘포인트'

# %% [markdown]
# # 데이터 로드

# %%
cust_demo = pd.read_csv('01.고객DEMO.txt')
shp_sale = pd.read_csv('02.쇼핑업종 상품구매.txt')
unshp_sale = pd.read_csv('03.쇼핑외 업종 상품구매.txt')
shp_nm = pd.read_csv('04.쇼핑업종 상품분류.txt')

# %%
cust_demo.columns = ['고객번호','성별','연령대','거주지']
shp_sale.columns = ['고객번호','영수증번호','업종','상품_소분류','점포코드','구매일자','구매시간','구매금액','구매수량']
unshp_sale.columns = ['고객번호','업종','이용월','이용금액','이용건수']
shp_nm.columns = ['업종','상품_소분류','상품_소분류명','상품_중분류명','상품_대분류명']

# %% [markdown]
# ## 고객데이터 EDA

# %%
print('#########  dim 확인  #########')
print(cust_demo.shape)
print('#########  data type 확인  #########')
print(cust_demo.dtypes)
cust_demo.head()
# Out:
# #########  dim 확인  #########
# (20000, 4)
# #########  data type 확인  #########
# 고객번호      int64
# 성별        int64
# 연령대      object
# 거주지     float64
# dtype: object
#    고객번호  성별    연령대    거주지
# 0     1   1  60PRD   52.0
# 1     2   2  60PRD   80.0
# 2     3   2  60PRD  620.0
# 3     4   1  60PRD  120.0
# 4     5   1  60PRD    NaN

# %%
# 거주지는 쓸필요 없는 정보니 날리자
cust_demo = cust_demo.drop(['거주지'], axis = 1)
# 고객번호 str 변환
cust_demo['고객번호'] = cust_demo['고객번호'].astype('str')

# %%
print('#########  연령대 확인  #########')
print(cust_demo.groupby('연령대')['고객번호'].count())
print('#########  성별 확인  #########')
print(cust_demo.groupby('성별')['고객번호'].count())
# Out:
# #########  연령대 확인  #########
# 연령대
# 20PRD    2339
# 30PRD    5053
# 40PRD    5183
# 50PRD    4744
# 60PRD    2681
# Name: 고객번호, dtype: int64
# #########  성별 확인  #########
# 성별
# 1     7815
# 2    12185
# Name: 고객번호, dtype: int64

# %% [markdown]
# ## 구매 데이터 EDA

# %%
print('#########  dim 확인  #########')
print(shp_sale.shape) # 364만건..
print('#########  data type 확인  #########')
print(shp_sale.dtypes)
shp_sale.head()
# 구매 업종이랑 상품 소분류명을 모르겠다... 정보를 합쳐야 겠음.
# PK설정을 위해 전처리 필요. ==> shp_nm 의 업종, 상품 소분류로 merge 필요.
# Out:
# #########  dim 확인  #########
# (3641082, 9)
# #########  data type 확인  #########
# 고객번호       int64
# 영수증번호      int64
# 업종        object
# 상품_소분류     int64
# 점포코드       int64
# 구매일자       int64
# 구매시간       int64
# 구매금액       int64
# 구매수량       int64
# dtype: object
#    고객번호  영수증번호   업종  상품_소분류  점포코드      구매일자  구매시간   구매금액  구매수량
# 0  4008   2108  A01     215     2  20150216    13  59600     2
# 1  6379   2109  A01      75    29  20150213    11  35000     1
# 2  6379   2109  A01     149     4  20150115    10  85000     1
# 3  8002   2110  A01     138    10  20151220    10  25000     1
# 4  8002   2110  A01     138    10  20151220    10  21000     1

# %%
print('#########  dim 확인  #########')
print(shp_nm.shape) # 3788건의 상품정보 존재
print('#########  data type 확인  #########')
print(shp_nm.dtypes)
shp_nm.head()
# Out:
# #########  dim 확인  #########
# (3788, 5)
# #########  data type 확인  #########
# 업종         object
# 상품_소분류      int64
# 상품_소분류명    object
# 상품_중분류명    object
# 상품_대분류명    object
# dtype: object
#     업종  상품_소분류    상품_소분류명 상품_중분류명 상품_대분류명
# 0  A04     341  단행본서적(직배)   특수점서적   서적/음반
# 1  A04       1       삼각김밥    삼각김밥      미반
# 2  A04       2  The커진삼각김밥    삼각김밥      미반
# 3  A04       3       말이김밥      김밥      미반
# 4  A04       4      트레이김밥      김밥      미반

# %%
shp_sale['고객번호'] = shp_sale['고객번호'].astype('str')
shp_sale['업종'] = shp_sale['업종'].astype('str')
shp_sale['상품_소분류'] = shp_sale['상품_소분류'].astype('str')
shp_nm['업종'] = shp_nm['업종'].astype('str')
shp_nm['상품_소분류'] = shp_nm['상품_소분류'].astype('str')

# %%
shp_sale_master = pd.merge(shp_sale,shp_nm,on = ['업종','상품_소분류'], how = 'left')

# %%
shp_sale_master.head()
# Out:
#    고객번호  영수증번호   업종 상품_소분류  점포코드      구매일자  구매시간   구매금액  구매수량 상품_소분류명 상품_중분류명  \
# 0  4008   2108  A01    215     2  20150216    13  59600     2   이지캐주얼     캐주얼
# 1  6379   2109  A01     75    29  20150213    11  35000     1    건강식품    건강식품
# 2  6379   2109  A01    149     4  20150115    10  85000     1     기초A     화장품
# 3  8002   2110  A01    138    10  20151220    10  25000     1      기타    섬유잡화
# 4  8002   2110  A01    138    10  20151220    10  21000     1      기타    섬유잡화
#
#   상품_대분류명              상품
# 0    여성의류  여성의류_캐주얼_이지캐주얼
# 1      식품    식품_건강식품_건강식품
# 2      잡화      잡화_화장품_기초A
# 3      잡화      잡화_섬유잡화_기타
# 4      잡화      잡화_섬유잡화_기타

# %%
# shp_sale_master[shp_sale_master['고객번호'] == '1'].sort_values(['구매일자','구매시간'])

# %%
shp_sale_master.head()
# Out:
#    고객번호  영수증번호   업종 상품_소분류  점포코드      구매일자  구매시간   구매금액  구매수량 상품_소분류명 상품_중분류명  \
# 0  4008   2108  A01    215     2  20150216    13  59600     2   이지캐주얼     캐주얼
# 1  6379   2109  A01     75    29  20150213    11  35000     1    건강식품    건강식품
# 2  6379   2109  A01    149     4  20150115    10  85000     1     기초A     화장품
# 3  8002   2110  A01    138    10  20151220    10  25000     1      기타    섬유잡화
# 4  8002   2110  A01    138    10  20151220    10  21000     1      기타    섬유잡화
#
#   상품_대분류명              상품
# 0    여성의류  여성의류_캐주얼_이지캐주얼
# 1      식품    식품_건강식품_건강식품
# 2      잡화      잡화_화장품_기초A
# 3      잡화      잡화_섬유잡화_기타
# 4      잡화      잡화_섬유잡화_기타

# %%
shp_sale_master["상품"] = shp_sale_master["상품_대분류명"] +"_" + shp_sale_master["상품_중분류명"] + "_" + shp_sale_master["상품_소분류명"]

# %%
# shp_sale_master.상품[shp_sale_master.업종 == 'B01'] = "호텔"
# shp_sale_master.상품[shp_sale_master.업종 == 'B02'] = "여행사"
# shp_sale_master.상품[shp_sale_master.업종 == 'B03'] = "면세점"
# shp_sale_master.상품[shp_sale_master.업종 == 'C01'] = "영화관"
# shp_sale_master.상품[shp_sale_master.업종 == 'C02'] = "테마파크"
# shp_sale_master.상품[shp_sale_master.업종 == 'C03'] = "야구관람"
# shp_sale_master.상품[shp_sale_master.업종 == 'D01'] = "롯데리아"
# shp_sale_master.상품[shp_sale_master.업종 == 'D02'] = "페밀리레스토랑"
# shp_sale_master.상품[shp_sale_master.업종 == 'D03'] = "엔젤리너스"

# %%
shp_sale_master.head()
# Out:
#    고객번호  영수증번호   업종 상품_소분류  점포코드      구매일자  구매시간   구매금액  구매수량 상품_소분류명 상품_중분류명  \
# 0  4008   2108  A01    215     2  20150216    13  59600     2   이지캐주얼     캐주얼
# 1  6379   2109  A01     75    29  20150213    11  35000     1    건강식품    건강식품
# 2  6379   2109  A01    149     4  20150115    10  85000     1     기초A     화장품
# 3  8002   2110  A01    138    10  20151220    10  25000     1      기타    섬유잡화
# 4  8002   2110  A01    138    10  20151220    10  21000     1      기타    섬유잡화
#
#   상품_대분류명              상품
# 0    여성의류  여성의류_캐주얼_이지캐주얼
# 1      식품    식품_건강식품_건강식품
# 2      잡화      잡화_화장품_기초A
# 3      잡화      잡화_섬유잡화_기타
# 4      잡화      잡화_섬유잡화_기타

# %%
all_data_demo2 = shp_sale_master[["고객번호","상품_중분류명"]]

# %%
len(all_data_demo2.상품_중분류명.unique())
# Out:
# 690

# %%
all_data_demo2.columns = ["고객번호","상품"]

# %%
all_data_demo3 = all_data_demo2.groupby(["고객번호"])["상품"].apply(','.join).reset_index()

# %%
# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.models import TfidfModel

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(sentence.split(",")) # deacc=True removes punctuations

data_words = list(sent_to_words(all_data_demo3.상품))
print(data_words[:1])
# Out:
# [['주방용품', '주방용품', '골프용품', '란제리/내의', '젓갈/반찬', '젓갈/반찬', '젓갈/반찬', '젓갈/반찬', '차/커피', '기타의류', '가공식품', '소형가전', '아동', '아동', '가공식품', '주방용품', '골프용품', '육류', '골프용품', '가공식품', '가공식품', '스포츠', '건강선물세트', '젓갈/반찬', '젓갈/반찬', '젓갈/반찬', '육류', '가공식품', '젓갈/반찬', '가공식품', '아동', '생활잡화', '차/커피', '가공식품', '농산물', '주류', '농산물', '아동', '차/커피', '란제리/내의', '가공식품', '골프용품', '가공식품', '셔츠', '골프용품', '식기', '골프용품', '트래디셔널', '차/커피', '육류', '농산물', '스포츠', '가공식품', '수산품', '스포츠']]

# %%
# Create Dictionary
id2word = corpora.Dictionary(data_words)

# Create Corpus  
texts = data_words

# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]

# View
print(corpus[:1])
# Out:
# [[(0, 10), (1, 1), (2, 6), (3, 1), (4, 3), (5, 2), (6, 1), (7, 1), (8, 1), (9, 1), (10, 3), (11, 1), (12, 4), (13, 3), (14, 8), (15, 1), (16, 3), (17, 4), (18, 1)]]

# %%
model = TfidfModel(corpus)  # fit model

# %%
tfidf_corpus = []
for i in range(0,len(corpus)-1) :
    tfidf_corpus.append(model[corpus[i]])

# %%
K = 8
D = len(corpus)
W = len(id2word)
# num_topics = 8
iterations = 1000 #iteration
alpha = 50/K #typical(Griffiths and Steyvers (2004) suggest)
eta = 200/W

# %%
# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
id2word=id2word,
num_topics=K,
random_state=100,
update_every=1,
chunksize=100,
passes=10,
alpha=alpha,
eta = eta,
per_word_topics=True)

# %%
# Plotting tools
import pyLDAvis
import pyLDAvis.gensim # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Visualize the topics
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word)

# %%
vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 2     -0.033736  0.346676       1        1  18.913280
# 7     -0.198069 -0.135303       2        1  16.807108
# 4      0.364641 -0.083110       3        1  12.864124
# 3     -0.177059  0.163077       4        1  12.246257
# 1      0.355427 -0.102374       5        1  11.455435
# 0     -0.237524 -0.099777       6        1  10.575661
# 6     -0.171353 -0.243374       7        1   9.566074
# 5      0.097673  0.154186       8        1   7.572056, topic_info=     Category           Freq   Term          Total  loglift  logprob
# term
# 0     Default  225393.000000   가공식품  225393.000000  30.0000  30.0000
# 19    Default  125462.000000    캐주얼  125462.000000  29.0000  29.0000
# 4     Default   70455.000000    농산물   70455.000000  28.0000  28.0000
# 44    Default   97562.000000     스낵   97562.000000  27.0000  27.0000
# 10    Default   43954.000000    스포츠   43954.000000  26.0000  26.0000
# 227   Default   40618.000000   가공우유   40618.000000  25.0000  25.0000
# 86    Default   48180.000000    화장품   48180.000000  24.0000  24.0000
# 153   Default   43836.000000     맥주   43836.000000  23.0000  23.0000
# 17    Default   38717.000000   차/커피   38717.000000  22.0000  22.0000
# 31    Default   70392.000000     라면   70392.000000  21.0000  21.0000
# 107   Default   43820.000000    균일가   43820.000000  20.0000  20.0000
# 267   Default   35672.000000     우유   35672.000000  19.0000  19.0000
# 93    Default   27478.000000    비스켓   27478.000000  18.0000  18.0000
# 46    Default   31405.000000   열매채소   31405.000000  17.0000  17.0000
# 12    Default   33030.000000     아동   33030.000000  16.0000  16.0000
# 104   Default   40790.000000     생수   40790.000000  15.0000  15.0000
# 51    Default   30088.000000    잎채소   30088.000000  14.0000  14.0000
# 108   Default   21513.000000  기초화장품   21513.000000  13.0000  13.0000
# 74    Default   29671.000000   국산과일   29671.000000  12.0000  12.0000
# 14    Default   24051.000000  젓갈/반찬   24051.000000  11.0000  11.0000
# 64    Default   41613.000000   탄산음료   41613.000000  10.0000  10.0000
# 250   Default   28033.000000    두채류   28033.000000   9.0000   9.0000
# 29    Default   26150.000000     두부   26150.000000   8.0000   8.0000
# 120   Default   40461.000000  종량제봉투   40461.000000   7.0000   7.0000
# 69    Default   46579.000000    흰우유   46579.000000   6.0000   6.0000
# 15    Default   22385.000000     주류   22385.000000   5.0000   5.0000
# 265   Default   37850.000000  아이스크림   37850.000000   4.0000   4.0000
# 78    Default   24485.000000   섬유잡화   24485.000000   3.0000   3.0000
# 161   Default   25904.000000    발효유   25904.000000   2.0000   2.0000
# 197   Default   25687.000000  쿠키케이크   25687.000000   1.0000   1.0000
# ...       ...            ...    ...            ...      ...      ...
# 544    Topic8    4577.279297   외산담배    4579.061523   2.5803  -4.0982
# 499    Topic8    4018.422852     주스    4020.238281   2.5803  -4.2284
# 129    Topic8    4124.459473     과자    4126.395020   2.5802  -4.2024
# 228    Topic8    3460.710693    간식빵    3462.501465   2.5802  -4.3779
# 376    Topic8    3154.125977    캔맥주    3155.945312   2.5801  -4.4706
# 373    Topic8    3124.056396    육가공    3125.857910   2.5801  -4.4802
# 410    Topic8    2960.261719   국산담배    2962.052979   2.5801  -4.5341
# 412    Topic8    2386.004883   냉장식품    2387.797363   2.5800  -4.7497
# 370    Topic8    2437.958496  공병공박스    2439.800781   2.5800  -4.7282
# 431    Topic8    2178.785645  파우치음료    2180.592041   2.5799  -4.8406
# 372    Topic8    2057.468506    봉지면    2059.273682   2.5798  -4.8979
# 326    Topic8    2150.223633   집중케어    2152.171387   2.5798  -4.8538
# 517    Topic8    1937.555054     김밥    1939.349487   2.5798  -4.9579
# 533    Topic8    1901.676758  스포츠음료    1903.499756   2.5797  -4.9766
# 268    Topic8    1982.854980     음료    1984.825806   2.5797  -4.9348
# 519    Topic8    1620.598999   샌드위치    1622.381836   2.5796  -5.1365
# 340    Topic8    1526.917358     반찬    1528.712402   2.5795  -5.1961
# 492    Topic8    1339.259766     고급    1341.072754   2.5794  -5.3272
# 424    Topic8    1289.015381     얼음    1290.822021   2.5793  -5.3655
# 225    Topic8    1277.091431  가공미반류    1278.906494   2.5793  -5.3747
# 227    Topic8   36183.589844   가공우유   40618.683594   2.4651  -2.0307
# 274    Topic8    8932.121094    차음료   10485.319336   2.4204  -3.4297
# 280    Topic8   10532.660156   커피음료   13291.035156   2.3481  -3.2649
# 479    Topic8    2702.505371    도시락    3541.302979   2.3104  -4.6252
# 104    Topic8   11744.156250     생수   40790.675781   1.3356  -3.1560
# 64     Topic8   11796.708008   탄산음료   41613.750000   1.3201  -3.1515
# 25     Topic8    4173.334473      껌    7647.003906   1.9751  -4.1906
# 116    Topic8    6570.625977   요구르트   46612.179688   0.6215  -3.7367
# 0      Topic8    8176.643555   가공식품  225393.437500  -0.7359  -3.5181
# 320    Topic8    2227.595703     소주   21410.480469   0.3177  -4.8184
#
# [376 rows x 6 columns], token_table=      Topic      Freq            Term
# term
# 99        7  0.999283     BABY/INFANT
# 331       7  0.999736          BOYS 1
# 377       7  0.999041          BOYS 2
# 100       7  0.999499     EDUCATION 1
# 20        7  0.999301     EDUCATION 2
# 101       7  0.999625           GIRLS
# 123       2  0.999721        LOCAL잎채소
# 102       7  0.999513  SPORTS/OUTDOOR
# 225       8  0.998509           가공미반류
# 0         3  0.817105            가공식품
# 0         5  0.146615            가공식품
# 0         8  0.036279            가공식품
# 516       2  0.068151            가공양곡
# 516       6  0.928926            가공양곡
# 227       4  0.109137            가공우유
# 227       8  0.890822            가공우유
# 494       3  0.159173              가구
# 494       5  0.563601              가구
# 494       6  0.088519              가구
# 494       7  0.188408              가구
# 70        1  0.999904            가정잡화
# 106       2  0.038441              간식
# 106       4  0.103249              간식
# 106       6  0.022545              간식
# 106       7  0.832335              간식
# 106       8  0.003363              간식
# 228       8  0.999566             간식빵
# 352       4  0.742572           간식용과자
# 352       6  0.182816           간식용과자
# 352       7  0.074042           간식용과자
# ...     ...       ...             ...
# 402       7  0.933802            필기도구
# 67        2  0.999090           한방식재류
# 403       2  0.039021          한우선물세트
# 403       6  0.953218          한우선물세트
# 512       2  0.998811              해초
# 224       2  0.300692               햄
# 224       4  0.498826               햄
# 224       6  0.199674               햄
# 224       7  0.000616               햄
# 368       3  0.089288            헤어케어
# 368       5  0.384626            헤어케어
# 368       8  0.525691            헤어케어
# 208       2  0.950510          호주산소고기
# 208       6  0.049292          호주산소고기
# 283       1  0.522538             화장지
# 283       2  0.014394             화장지
# 283       4  0.009299             화장지
# 283       6  0.415718             화장지
# 283       7  0.037925             화장지
# 86        1  0.007804             화장품
# 86        3  0.160667             화장품
# 86        5  0.831480             화장품
# 209       2  0.006768           훼이셜케어
# 209       6  0.883958           훼이셜케어
# 209       7  0.108746           훼이셜케어
# 69        2  0.532256             흰우유
# 69        4  0.404774             흰우유
# 69        6  0.000043             흰우유
# 69        7  0.019386             흰우유
# 69        8  0.043496             흰우유
#
# [588 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[3, 8, 5, 4, 2, 1, 7, 6])

# %%
# # Build LDA model
# lda_model = gensim.models.ldamodel.LdaModel(corpus=tfidf_corpus,
# id2word=id2word,
# num_topics=K,
# random_state=100,
# update_every=1,
# chunksize=100,
# passes=10,
# alpha=alpha,
# eta = eta,
# per_word_topics=True)

# # Visualize the topics
# pyLDAvis.enable_notebook()
# vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word)
# vis

# %%
pyLDAvis.save_html(vis, 'lda.html')
