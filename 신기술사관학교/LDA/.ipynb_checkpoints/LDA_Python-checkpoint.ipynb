# %%
import os
import pandas as pd

# %%
os.getcwd()
# Out:
# '/Users/arnorfati/Data_Scientist/LDA'

# %%
all_data_demo = pd.read_csv("all_data_demo2.csv")

# %%
all_data_demo["item"] = all_data_demo["PD_H_NM"] +"_" + all_data_demo["PD_M_NM"] + "_" + all_data_demo["PD_S_NM"]

# %%
all_data_demo.item[all_data_demo.BIZ_UNIT == 'B01'] = "호텔"
all_data_demo.item[all_data_demo.BIZ_UNIT == 'B02'] = "여행사"
all_data_demo.item[all_data_demo.BIZ_UNIT == 'B03'] = "면세점"
all_data_demo.item[all_data_demo.BIZ_UNIT == 'C01'] = "영화관"
all_data_demo.item[all_data_demo.BIZ_UNIT == 'C02'] = "테마파크"
all_data_demo.item[all_data_demo.BIZ_UNIT == 'C03'] = "야구관람"
all_data_demo.item[all_data_demo.BIZ_UNIT == 'D01'] = "롯데리아"
all_data_demo.item[all_data_demo.BIZ_UNIT == 'D02'] = "페밀리레스토랑"
all_data_demo.item[all_data_demo.BIZ_UNIT == 'D03'] = "엔젤리너스"
# Out:
# /Users/arnorfati/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/arnorfati/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/arnorfati/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
all_data_demo2 = all_data_demo[["ID","item"]]

# %%
del all_data_demo

# %%
all_data_demo2.head()
# Out:
#    ID          item
# 0   1      식품_육류_우육
# 1   1      식품_육류_돈육
# 2   1      식품_육류_계육
# 3   1  식품_차/커피_디저트류
# 4   1  식품_차/커피_디저트류

# %%
all_data_demo3 = all_data_demo2.groupby(["ID"])["item"].apply(','.join).reset_index()

# %%
# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.models import TfidfModel

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(sentence.split(",")) # deacc=True removes punctuations

data_words = list(sent_to_words(all_data_demo3.item))

print(data_words[:1])
# Out:
# [['식품_육류_우육', '식품_육류_돈육', '식품_육류_계육', '식품_차/커피_디저트류', '식품_차/커피_디저트류', '식품_차/커피_디저트류', '식품_가공식품_에스닉푸드', '식품_농산물_청과', '식품_농산물_유기농채소', '식품_농산물_유기농채소', '식품_수산품_기타생선', '식품_가공식품_초밥', '식품_가공식품_초밥', '식품_가공식품_초밥', '식품_가공식품_제과', '제빵', '식품_젓갈/반찬_어묵', '식품_젓갈/반찬_어묵', '식품_젓갈/반찬_어묵', '식품_젓갈/반찬_어묵', '식품_젓갈/반찬_어묵', '식품_젓갈/반찬_어묵', '식품_젓갈/반찬_어묵', '식품_젓갈/반찬_어묵', '식품_주류_음료', '식품_차/커피_수입식품', '식품_가공식품_식당가 한식', '식품_가공식품_식당가 한식', '식품_가공식품_식당가 한식', '식품_가공식품_식당가 중식', '식품_가공식품_식당가 일식', '남성의류_트래디셔널_수입화', '여성의류_란제리/내의_란제리', '여성의류_란제리/내의_란제리', '여성의류_기타의류_홈웨어', '남성의류_셔츠_셔츠단기행사', '스포츠_스포츠_L/C 아웃도어', '스포츠_스포츠_디스커버리', '스포츠_스포츠_몬츄라', '스포츠_골프용품_N/B골프의류', '스포츠_골프용품_N/B골프의류', '스포츠_골프용품_N/B골프의류', '스포츠_골프용품_N/B골프의류', '스포츠_골프용품_L/C골프의류', '스포츠_골프용품_L/C골프의류', '아동_아동_유아복', '아동_아동_유아복', '아동_아동_유아복', '아동_아동_내의', '가전_소형가전_수입청소기 외', '가정_주방용품_수입주방', '가정_주방용품_수입주방', '가정_주방용품_주방잡화', '가정_생활잡화_기능성침대', '가정_식기_수입도자기', '건강식품_건강선물세트_홍삼선물세트', '면세점', '엔젤리너스', '영화관', '면세점', '영화관', '테마파크', '엔젤리너스', '면세점', '엔젤리너스', '면세점']]

# %%
# Create Dictionary
id2word = corpora.Dictionary(data_words)

# Create Corpus  
texts = data_words

# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]

# View
print(corpus[:1])
# Out:
# [[(0, 1), (1, 1), (2, 1), (3, 2), (4, 1), (5, 1), (6, 1), (7, 1), (8, 4), (9, 2), (10, 4), (11, 1), (12, 1), (13, 1), (14, 1), (15, 1), (16, 3), (17, 1), (18, 1), (19, 3), (20, 2), (21, 1), (22, 1), (23, 1), (24, 1), (25, 1), (26, 8), (27, 1), (28, 3), (29, 1), (30, 1), (31, 3), (32, 3), (33, 1), (34, 2), (35, 2), (36, 1), (37, 1)]]

# %%
model = TfidfModel(corpus)  # fit model

# %%
tfidf_corpus = []
for i in range(0,len(corpus)-1) :
    tfidf_corpus.append(model[corpus[i]])

# %%
K = 14
D = len(corpus)
W = len(id2word)
num_topics = 14
iterations = 1000 #iteration
alpha = 50/K #typical(Griffiths and Steyvers (2004) suggest)
eta = 200/W

# %%
# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
id2word=id2word,
num_topics=K,
random_state=100,
update_every=1,
chunksize=100,
passes=10,
alpha=alpha,
eta = eta,
per_word_topics=True)

# %%
# Plotting tools
import pyLDAvis
import pyLDAvis.gensim # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Visualize the topics
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word)
vis
# Out:
# /Users/arnorfati/anaconda/lib/python3.6/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 6     -0.027989 -0.148146       1        1  17.711309
# 13     0.291629  0.079951       2        1  12.858107
# 11     0.296679  0.048731       3        1  10.423315
# 12     0.316194  0.071928       4        1   9.393469
# 1      0.226718  0.025150       5        1   8.180758
# 10    -0.178085  0.188537       6        1   6.113576
# 5     -0.052433 -0.148197       7        1   5.562160
# 4     -0.188554  0.124091       8        1   5.442474
# ...

# %%
# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=tfidf_corpus,
id2word=id2word,
num_topics=K,
random_state=100,
update_every=1,
chunksize=100,
passes=10,
alpha=alpha,
eta = eta,
per_word_topics=True)

# %%
# Visualize the topics
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word)
vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster      Freq
# topic
# 3     -0.041524 -0.307485       1        1  9.488083
# 8     -0.020519 -0.300050       2        1  8.640168
# 12     0.209748  0.070756       3        1  8.023399
# 13     0.211407  0.055622       4        1  7.965565
# 11     0.101837  0.011845       5        1  7.879636
# 10     0.221991  0.079745       6        1  7.805220
# 2     -0.077750 -0.033017       7        1  7.724803
# 5      0.197093  0.017030       8        1  7.529750
# 7     -0.200899  0.139368       9        1  6.945667
# 9     -0.044268  0.089320      10        1  6.134731
# 1     -0.202163  0.132969      11        1  5.797477
# 0     -0.166516  0.100105      12        1  5.526327
# 4     -0.089887 -0.045343      13        1  5.507638
# 6     -0.098548 -0.010866      14        1  5.031528, topic_info=     Category          Freq                 Term         Total  loglift  \
# term
# ...
